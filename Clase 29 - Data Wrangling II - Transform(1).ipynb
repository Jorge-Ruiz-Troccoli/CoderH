# %% [markdown]
# # CLASE 28 - Data Wrangling II
# ### Coderhouse - Data Science
# Profe Jorge Ruiz

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Ejemplos print

# %%
print('Pero', 'no', 'incluyendo', sep='**')
# Out:
# Pero**no**incluyendo

# %%
print('Pero', 'no', 'incluyendo', sep='')
# Out:
# Peronoincluyendo

# %%
manzana=20

print ("el precio de la manzana:", manzana, "pesos")
# Out:
# el precio de la manzana: 20 pesos

# %% [markdown]
# Un f-string es una forma de formatear cadenas de texto en Python introducida a partir de la versión 3.6. El término "f-string" proviene del prefijo "f" que se coloca antes de la cadena entre comillas.
#
# Los f-strings permiten la interpolación de variables y expresiones dentro de las cadenas de forma más concisa y legible. Al utilizar un f-string, puedes incluir expresiones y variables dentro de la cadena utilizando llaves {}. Estas expresiones se evalúan y se insertan en la cadena resultante.
#
# Aquí hay un ejemplo simple que muestra cómo usar f-strings:

# %%
g=9.8

f"el valor de aceleración de la gravedad en la tierra es {g} m/s2"
# Out:
# 'el valor de aceleración de la gravedad en la tierra es 9.8 m/s2'

# %%
#usando print se puede hacer lo mismo pero es menos elegante
nombre="Jorge"
ocupación="profe"

print("Hola, me llamo", nombre, "y soy", ocupación, "en CH")
# Out:
# Hola, me llamo Jorge y soy profe en CH

# %%
numero = 3.14159
cadena = f"El valor de PI es {numero:.2f}"
cadena
# Out:
# 'El valor de PI es 3.14'

# %%
nombres = ["Alice", "Bob", "Charlie"]
diccionario = {"nombre": "Alice", "edad": 25}

cadena1 = f"El primer nombre es {nombres[0]}"
cadena2 = f"El nombre es {diccionario['nombre']} y tiene {diccionario['edad']} años"

print(cadena1)
print(cadena2)
# Out:
# El primer nombre es nombres[0]
# El nombre es Alice y tiene 25 años

# %% [markdown]
# El operador %, se usaba en el formateo de cadenas en Python antes de la incorporación de los f-strings (desde la versión 3.6). Aunque aún es válido, se recomienda utilizar f-strings en su lugar, ya que proporcionan una sintaxis más legible,poderosa y "pytonesca".

# %%
# uso del operador % en formateo de cadenas
nombre = "Juan"
edad = 10

cadena = "Hola, me llamo %s y tengo %d años." % (nombre, edad)
print(cadena)

# %s para una cadena
# %d para un número entero
# %.2f para un número de punto flotante.
# Out:
# Hola, me llamo Juan y tengo 10 años.

# %% [markdown]
# # Casos duplicados:

# %%
# Datos de ejemplo
data = {'Nombre': ['Juan', 'María', 'Pedro', 'Ana', 'María', 'María'],
        'Edad': [25, 30, 35, 40, 30, 15]}

edades = pd.DataFrame(data)

edades
# Out:
#   Nombre  Edad
# 0   Juan    25
# 1  María    30
# 2  Pedro    35
# 3    Ana    40
# 4  María    30
# 5  María    15

# %%
# Detección de duplicados
duplicados = edades.duplicated()

# Mostrar los duplicados
print("Duplicados:")
edades[duplicados]
# Out:
# Duplicados:
#   Nombre  Edad
# 4  María    30

# %%
# Eliminación de duplicados
df_sin_duplicados = edades.drop_duplicates()

# Mostrar el DataFrame sin duplicados
print("\nDataFrame sin duplicados:")
df_sin_duplicados
# Out:
# DataFrame sin duplicados:
#   Nombre  Edad
# 0   Juan    25
# 1  María    30
# 2  Pedro    35
# 3    Ana    40
# 5  María    15

# %%
# detección basados en una columna

duplicados = edades.duplicated("Nombre")

# Mostrar los duplicados
print("Duplicados:")
edades[duplicados]
# Out:
# Duplicados:
#   Nombre  Edad
# 4  María    30
# 5  María    15

# %%
# Eliminación de duplicados
duplicados = edades.drop_duplicates("Nombre") #faltaba seleccionar la columna "Nombre" para hacer el drop

# si usamos keep="last" mantenemos solamente a María de 15 años.

# Mostrar el DataFrame sin duplicados
print("\nDataFrame sin duplicados:")
duplicados
# Out:
# DataFrame sin duplicados:
#   Nombre  Edad
# 0   Juan    25
# 2  Pedro    35
# 3    Ana    40
# 5  María    15

# %%
df = sns.load_dataset('tips') # Propinas en un restaurante
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['sex'].value_counts(normalize=True)
# Out:
# Male      0.643443
# Female    0.356557
# Name: sex, dtype: float64

# %%
round(df['sex'].value_counts(normalize=True)*100,1)
# Out:
# Male      64.3
# Female    35.7
# Name: sex, dtype: float64

# %%
df.sort_values('tip').head(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 75        10.51  1.25    Male     No   Sat  Dinner     2
# 135        8.51  1.25  Female     No  Thur   Lunch     2

# %%
# top 10 - 10 más grandes
df.sort_values('tip', ascending=False).head(10)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 88        24.71   5.85    Male     No  Thur   Lunch     2

# %%
df.nlargest(10, 'tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 88        24.71   5.85    Male     No  Thur   Lunch     2

# %% [markdown]
# # Pivot table o tabla pivote

# %% [markdown]
# #### Indice

# %%
"""
En este ejemplo se desea agrupar los datos por la columna 'sex' y utilizarla como índice de la tabla dinámica.

Por defecto, calculará la media de cada columna numérica, pero se pueden especificar otras funciones de agregación
utilizando el parámetro aggfunc
"""

pd.pivot_table(df,
               index='sex')
# Out:
# <ipython-input-29-a369ca3c81ee>:8: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df,
#             size       tip  total_bill
# sex
# Male    2.630573  3.089618   20.744076
# Female  2.459770  2.833448   18.056897

# %%
#las tablas de pivote funcionan de forma similar al groupby
df.groupby(by=["sex"]).mean()
# Out:
# <ipython-input-30-1bc2398a8c76>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by=["sex"]).mean()
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %%
df2 = pd.pivot_table(df,
               index=['sex', 'day'])

df2
# Out:
# <ipython-input-31-d22ea6782bf1>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df2 = pd.pivot_table(df,
#                  size       tip  total_bill
# sex    day
# Male   Thur  2.433333  2.980333   18.714667
#        Fri   2.100000  2.693000   19.857000
#        Sat   2.644068  3.083898   20.802542
#        Sun   2.810345  3.220345   21.887241
# Female Thur  2.468750  2.575625   16.715312
#        Fri   2.111111  2.781111   14.145556
#        Sat   2.250000  2.801786   19.680357
#        Sun   2.944444  3.367222   19.872222

# %%
df.groupby(by=["sex", "day"]).mean()
# Out:
# <ipython-input-32-98b1e0e340d6>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by=["sex", "day"]).mean()
#              total_bill       tip      size
# sex    day
# Male   Thur   18.714667  2.980333  2.433333
#        Fri    19.857000  2.693000  2.100000
#        Sat    20.802542  3.083898  2.644068
#        Sun    21.887241  3.220345  2.810345
# Female Thur   16.715312  2.575625  2.468750
#        Fri    14.145556  2.781111  2.111111
#        Sat    19.680357  2.801786  2.250000
#        Sun    19.872222  3.367222  2.944444

# %%
pd.pivot_table(df,
               index=['smoker', 'sex'])
# Out:
# <ipython-input-33-502518c118d1>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df,
#                    size       tip  total_bill
# smoker sex
# Yes    Male    2.500000  3.051167   22.284500
#        Female  2.242424  2.931515   17.977879
# No     Male    2.711340  3.113402   19.791237
#        Female  2.592593  2.773519   18.105185

# %% [markdown]
# #### Valores

# %%
pd.pivot_table(df,
               index=['sex', 'smoker'],
               values=['tip'])
# Out:
#                     tip
# sex    smoker
# Male   Yes     3.051167
#        No      3.113402
# Female Yes     2.931515
#        No      2.773519

# %% [markdown]
# #### Agregación

# %%
pd.pivot_table(df,
               index=['sex', 'smoker'],
               values=['tip'],
               aggfunc="max")
# Out:
#                 tip
# sex    smoker
# Male   Yes     10.0
#        No       9.0
# Female Yes      6.5
#        No       5.2

# %%
df3 = pd.pivot_table(df,
               index=['sex', 'smoker'],
               values=['tip'],
               aggfunc=[np.sum, np.mean])

df3 = df3.rename(columns={'sum': 'suma', 'mean': 'media'})
df3
# Out:
#                  suma     media
#                   tip       tip
# sex    smoker
# Male   Yes     183.07  3.051167
#        No      302.00  3.113402
# Female Yes      96.74  2.931515
#        No      149.77  2.773519

# %%
df3 = df.groupby(['sex', 'smoker'])['tip'].agg(['sum', 'mean'])
df3 = df3.rename(columns={'sum': 'suma', 'mean': 'media'})
df3
# Out:
#                  suma     media
# sex    smoker
# Male   Yes     183.07  3.051167
#        No      302.00  3.113402
# Female Yes      96.74  2.931515
#        No      149.77  2.773519

# %%
df3.unstack('sex')
# Out:
#           suma             media
# sex       Male  Female      Male    Female
# smoker
# Yes     183.07   96.74  3.051167  2.931515
# No      302.00  149.77  3.113402  2.773519

# %%
pd.pivot_table(df,
               index=['sex', 'smoker'],
               values=['day'],
               aggfunc=len)
# Out:
#                day
# sex    smoker
# Male   Yes      60
#        No       97
# Female Yes      33
#        No       54

# %%
pd.pivot_table(df,
               index=['sex', 'smoker'],
               values=['day'],
               aggfunc= pd.Series.nunique)
# Out:
#                day
# sex    smoker
# Male   Yes       4
#        No        4
# Female Yes       4
#        No        4

# %%
df.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# #### Columnas

# %%
a = pd.pivot_table(df,
               index=['sex'],
               columns= ['smoker'],
               values=['tip'],
               aggfunc=len)
a
# Out:
#        tip
# smoker Yes  No
# sex
# Male    60  97
# Female  33  54

# %%
a = pd.pivot_table(df,
               index=['sex'],
               columns= ['smoker'],
               values=['tip'],
               aggfunc=np.mean)
a
# Out:
#              tip
# smoker       Yes        No
# sex
# Male    3.051167  3.113402
# Female  2.931515  2.773519

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Totales

# %%
pd.pivot_table(df,
               index=['sex'],
               columns= ['smoker'],
               values=['tip'],
               aggfunc="count",
               margins=True)
# Out:
#        tip
# smoker Yes   No  All
# sex
# Male    60   97  157
# Female  33   54   87
# All     93  151  244

# %%
pd.pivot_table(df,
               index=['sex'],
               columns= ['smoker'],
               values=['tip'],
               aggfunc="count",
               margins=False)
# Out:
#        tip
# smoker Yes  No
# sex
# Male    60  97
# Female  33  54

# %% [markdown]
# # GROUPBY

# %%
df['tip'].groupby(df['sex']).mean()
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
df[['tip', 'total_bill']].groupby(df['sex']).sum()
# Out:
#            tip  total_bill
# sex
# Male    485.07     3256.82
# Female  246.51     1570.95

# %%
df['tip'].groupby(df['sex']).count()
# Out:
# sex
# Male      157
# Female     87
# Name: tip, dtype: int64

# %% [markdown]
# # APPLY

# %%
df['tip'].apply(np.sqrt)
# Out:
# 0      1.004988
# 1      1.288410
# 2      1.870829
# 3      1.819341
# 4      1.900000
#          ...
# 239    2.433105
# 240    1.414214
# 241    1.414214
# 242    1.322876
# 243    1.732051
# Name: tip, Length: 244, dtype: float64

# %%
def cuadrado_mas1(x):
    return x*x+1

cuadrado_mas1(2)
# Out:
# 5

# %%
# podemos crear la función que queramos y aplicarla con .apply()

df['tip_2'] = df['tip'].apply(cuadrado_mas1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size    tip_2
# 0         16.99  1.01  Female     No   Sun  Dinner     2   2.0201
# 1         10.34  1.66    Male     No   Sun  Dinner     3   3.7556
# 2         21.01  3.50    Male     No   Sun  Dinner     3  13.2500
# 3         23.68  3.31    Male     No   Sun  Dinner     2  11.9561
# 4         24.59  3.61  Female     No   Sun  Dinner     4  14.0321
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  36.0464
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   5.0000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   5.0000
# 242       17.82  1.75    Male     No   Sat  Dinner     2   4.0625
# 243       18.78  3.00  Female     No  Thur  Dinner     2  10.0000
#
# [244 rows x 8 columns]

# %%
# podemos concatenar los apply que necesitemos

df['tip'].apply(cuadrado_mas1).apply(np.sqrt)
# Out:
# 0      1.421302
# 1      1.937937
# 2      3.640055
# 3      3.457759
# 4      3.745944
#          ...
# 239    6.003865
# 240    2.236068
# 241    2.236068
# 242    2.015564
# 243    3.162278
# Name: tip, Length: 244, dtype: float64

# %%
df[['tip_2', 'total_bill_2', "size_2"]] = df[['tip', 'total_bill', "size"]].apply(np.sqrt)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size     tip_2  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2  1.004988
# 1         10.34  1.66    Male     No   Sun  Dinner     3  1.288410
# 2         21.01  3.50    Male     No   Sun  Dinner     3  1.870829
# 3         23.68  3.31    Male     No   Sun  Dinner     2  1.819341
# 4         24.59  3.61  Female     No   Sun  Dinner     4  1.900000
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  2.433105
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  1.414214
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  1.414214
# 242       17.82  1.75    Male     No   Sat  Dinner     2  1.322876
# 243       18.78  3.00  Female     No  Thur  Dinner     2  1.732051
#
#      total_bill_2    size_2
# 0        4.121893  1.414214
# 1        3.215587  1.732051
# 2        4.583667  1.732051
# 3        4.866210  1.414214
# 4        4.958831  2.000000
# ..            ...       ...
# 239      5.387950  1.732051
# 240      5.213444  1.414214
# 241      4.761302  1.414214
# 242      4.221374  1.414214
# 243      4.333590  1.414214
#
# [244 rows x 10 columns]

# %%
df['tip_2'] = df['tip_2'].astype(str)
df['tip_2'] = df['tip_2'].astype(float)
df['tip_2'] = df['tip_2'].astype('category')
df['tip_2'] = df['tip_2'].astype('object')
df['tip_2'] = df['tip_2'].astype('int16')
df['tip_2'] = df['tip_2'].astype('float32')

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['tip'].value_counts()

# %%
df['day'].value_counts(normalize=True)

# %%
df['day'].value_counts(normalize=True, dropna=False)

# %%
df['day'].value_counts( dropna=False)

# %%
df.loc[0, 'day'] = np.NaN

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_2  total_bill_2  \
# 0         16.99  1.01  Female     No   NaN  Dinner     2    1.0      4.121893
# 1         10.34  1.66    Male     No   Sun  Dinner     3    1.0      3.215587
# 2         21.01  3.50    Male     No   Sun  Dinner     3    1.0      4.583667
# 3         23.68  3.31    Male     No   Sun  Dinner     2    1.0      4.866210
# 4         24.59  3.61  Female     No   Sun  Dinner     4    1.0      4.958831
# ..          ...   ...     ...    ...   ...     ...   ...    ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    2.0      5.387950
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    1.0      5.213444
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    1.0      4.761302
# 242       17.82  1.75    Male     No   Sat  Dinner     2    1.0      4.221374
# 243       18.78  3.00  Female     No  Thur  Dinner     2    1.0      4.333590
#
#        size_2
# 0    1.414214
# 1    1.732051
# 2    1.732051
# 3    1.414214
# 4    2.000000
# ..        ...
# 239  1.732051
# 240  1.414214
# 241  1.414214
# 242  1.414214
# 243  1.414214
#
# [244 rows x 10 columns]

# %%
df.sort_values('total_bill', ascending=True).head(3)
# Out:
#      total_bill  tip     sex smoker  day    time  size  tip_2  total_bill_2  \
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1    1.0      1.752142
# 92         5.75  1.0  Female    Yes  Fri  Dinner     2    1.0      2.397916
# 111        7.25  1.0  Female     No  Sat  Dinner     1    1.0      2.692582
#
#        size_2
# 67   1.000000
# 92   1.414214
# 111  1.000000

# %%
df.nlargest(3, 'total_bill')
# Out:
#      total_bill    tip   sex smoker  day    time  size  tip_2  total_bill_2  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3    3.0      7.128113
# 212       48.33   9.00  Male     No  Sat  Dinner     4    3.0      6.951978
# 59        48.27   6.73  Male     No  Sat  Dinner     4    2.0      6.947661
#
#        size_2
# 170  1.732051
# 212  2.000000
# 59   2.000000

# %%
a = pd.pivot_table(df,
               index=['sex', 'smoker'],
               values=['tip', 'total_bill'])
a
# Out:
#                     tip  total_bill
# sex    smoker
# Male   Yes     3.051167   22.284500
#        No      3.113402   19.791237
# Female Yes     2.931515   17.977879
#        No      2.773519   18.105185

# %%
a.loc['Male','Yes']
# Out:
# tip            3.051167
# total_bill    22.284500
# Name: (Male, Yes), dtype: float64

# %%
a.loc['Male']
# Out:
#              tip  total_bill
# smoker
# Yes     3.051167   22.284500
# No      3.113402   19.791237

# %%
a.iloc[a.index.get_level_values('smoker') == 'Yes']
# Out:
#                     tip  total_bill
# sex    smoker
# Male   Yes     3.051167   22.284500
# Female Yes     2.931515   17.977879

# %%
df = sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6428  1.06    0.0   6.36   green  credit card      East Harlem North
# 6429  0.00    0.0  58.80   green  credit card                Jamaica
# 6430  0.00    0.0  17.30   green         cash    Crown Heights North
# 6431  0.00    0.0   6.80   green  credit card          East New York
# 6432  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6433 rows x 14 columns]

# %%
df.dtypes
# Out:
# pickup             datetime64[ns]
# dropoff            datetime64[ns]
# passengers                  int64
# distance                  float64
# fare                      float64
# tip                       float64
# tolls                     float64
# total                     float64
# color                      object
# payment                    object
# pickup_zone                object
# dropoff_zone               object
# pickup_borough             object
# dropoff_borough            object
# dtype: object

# %%
df['pickup'] = pd.to_datetime(df['pickup'])
df['dropoff'] = pd.to_datetime(df['dropoff'])

# %%
df['pickup_day'] = df['pickup'].dt.day
df['pickup_weekday'] = df['pickup'].dt.weekday
df['pickup_month'] = df['pickup'].dt.month
df['pickup_hour'] = df['pickup'].dt.hour
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6428  1.06    0.0   6.36   green  credit card      East Harlem North
# 6429  0.00    0.0  58.80   green  credit card                Jamaica
# 6430  0.00    0.0  17.30   green         cash    Crown Heights North
# 6431  0.00    0.0   6.80   green  credit card          East New York
# 6432  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough  \
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
#       pickup_day  pickup_weekday  pickup_month  pickup_hour
# 0             23               5             3           20
# 1              4               0             3           16
# 2             27               2             3           17
# 3             10               6             3            1
# 4             30               5             3           13
# ...          ...             ...           ...          ...
# 6428          31               6             3            9
# 6429          31               6             3           17
# 6430          23               5             3           22
# 6431           4               0             3           10
# 6432          13               2             3           19
#
# [6433 rows x 18 columns]

# %%
pd.pivot_table(df,
               columns=['pickup_weekday'],
               index=['pickup_hour'],
               values=['passengers'],
               aggfunc=np.sum,
               fill_value=0,
               margins=True).apply(np.sqrt)
# Out:
#                passengers                                              \
# pickup_weekday          0          1          2          3          4
# pickup_hour
# 0                3.741657   4.123106   5.196152   5.916080   8.544004
# 1                1.414214   3.464102   3.464102   5.385165   4.358899
# 2                2.449490   1.414214   3.162278   2.828427   5.567764
# 3                1.000000   1.000000   2.449490   3.605551   4.123106
# 4                1.732051   3.316625   0.000000   2.449490   3.872983
# 5                2.645751   3.872983   3.000000   2.645751   4.242641
# 6                6.164414   6.708204   4.795832   4.795832   6.244998
# 7                6.557439   6.557439   8.000000   7.549834   7.745967
# 8                8.366600   6.708204   8.888194   8.246211  10.583005
# 9                7.211103   9.848858   9.949874   8.246211   8.246211
# 10               7.810250   7.211103   9.643651   7.615773   8.774964
# 11               6.708204   6.557439   8.124038   7.280110   7.549834
# 12               7.211103   8.185353   8.944272   7.874008   7.483315
# 13               6.480741   7.348469   9.165151   8.185353   7.681146
# 14               7.348469   9.539392   9.539392   7.745967  10.295630
# 15               8.246211   8.366600   8.306624   8.831761   7.745967
# 16               8.306624   8.124038   8.888194   8.602325   9.327379
# 17               8.124038   8.062258   8.774964   8.124038  10.488088
# 18               8.717798   8.944272  10.954451  10.954451   9.746794
# 19               8.426150   9.380832   8.944272   9.539392  10.392305
# 20               8.602325   8.888194   9.539392   8.426150   9.273618
# 21               8.544004   9.000000   8.544004  10.344080   9.848858
# 22               8.660254   9.055385   9.380832   8.124038   9.539392
# 23               5.385165   7.348469   7.681146   7.071068  10.954451
# All             33.030289  35.496479  38.457769  36.565011  40.755368
#
#
# pickup_weekday          5          6        All
# pickup_hour
# 0                9.055385   8.831761  18.055470
# 1                7.810250   7.681146  13.928388
# 2                7.211103   6.633250  12.369317
# 3                4.690416   6.708204  10.246951
# 4                5.385165   5.567764   9.746794
# 5                2.828427   3.464102   8.717798
# 6                3.741657   4.472136  14.212670
# 7                5.000000   5.477226  17.944358
# 8                7.071068   6.403124  21.563859
# 9                7.549834   7.937254  22.449944
# 10               8.544004   8.717798  22.135944
# 11              11.224972   9.165151  21.771541
# 12               9.273618   9.746794  22.315914
# 13               9.746794   9.380832  22.113344
# 14              10.344080   9.695360  24.556058
# 15               8.000000   8.660254  22.000000
# 16               9.380832   8.000000  22.956481
# 17              10.000000   8.124038  23.452079
# 18               9.949874   7.681146  25.475478
# 19              11.135529   8.124038  25.059928
# 20               9.110434   8.000000  23.409400
# 21               6.855655   7.141428  23.000000
# 22               9.539392   6.557439  23.151674
# 23              10.000000   6.557439  21.330729
# All             41.024383  37.296112  99.508794

# %%
pd.pivot_table(df,
               index=['pickup_day'],
               values=['passengers'],
               columns=['pickup_month'],
               aggfunc=np.sum,
               fill_value=0)
# Out:
#              passengers
# pickup_month          2    3
# pickup_day
# 1                     0  370
# 2                     0  310
# 3                     0  264
# 4                     0  267
# 5                     0  382
# 6                     0  390
# 7                     0  331
# 8                     0  332
# 9                     0  325
# 10                    0  301
# 11                    0  316
# 12                    0  320
# 13                    0  355
# 14                    0  358
# 15                    0  299
# 16                    0  349
# 17                    0  278
# 18                    0  274
# 19                    0  292
# 20                    0  382
# 21                    0  320
# 22                    0  348
# 23                    0  340
# 24                    0  252
# 25                    0  234
# 26                    0  266
# 27                    0  352
# 28                    1  327
# 29                    0  312
# 30                    0  359
# 31                    0  296

# %%
pd.pivot_table(df,
               index=['pickup_month', 'pickup_day'],
               values=['passengers'],
               aggfunc=np.sum,
               fill_value=0)
# Out:
#                          passengers
# pickup_month pickup_day
# 2            28                   1
# 3            1                  370
#              2                  310
#              3                  264
#              4                  267
#              5                  382
#              6                  390
#              7                  331
#              8                  332
#              9                  325
#              10                 301
#              11                 316
#              12                 320
#              13                 355
#              14                 358
#              15                 299
#              16                 349
#              17                 278
#              18                 274
#              19                 292
#              20                 382
#              21                 320
#              22                 348
#              23                 340
#              24                 252
#              25                 234
#              26                 266
#              27                 352
#              28                 327
#              29                 312
#              30                 359
#              31                 296

# %%
df['passengers'].groupby(df['pickup_day']).sum()
# Out:
# pickup_day
# 1     370
# 2     310
# 3     264
# 4     267
# 5     382
# 6     390
# 7     331
# 8     332
# 9     325
# 10    301
# 11    316
# 12    320
# 13    355
# 14    358
# 15    299
# 16    349
# 17    278
# 18    274
# 19    292
# 20    382
# 21    320
# 22    348
# 23    340
# 24    252
# 25    234
# 26    266
# 27    352
# 28    328
# 29    312
# 30    359
# 31    296
# Name: passengers, dtype: int64

# %%
df.distance.describe()
# Out:
# count    6433.000000
# mean        3.024617
# std         3.827867
# min         0.000000
# 25%         0.980000
# 50%         1.640000
# 75%         3.210000
# max        36.700000
# Name: distance, dtype: float64

# %%
df['cat'] = ""
df.loc[df.distance<=3,'cat'] = "<=3"
df.loc[df.distance>3 ,'cat'] = ">3"

# %%
df.cat.value_counts(normalize=True)
# Out:
# <=3    0.732473
# >3     0.267527
# Name: cat, dtype: float64

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough', 'pickup_day', 'pickup_weekday',
#        'pickup_month', 'pickup_hour', 'cat'],
#       dtype='object')

# %%
pd.pivot_table(df,
               index=['payment'],
               columns=['cat'],
               values=['total'],
               aggfunc=np.sum)
# Out:
#                 total
# cat               <=3        >3
# payment
# cash         15367.67  11226.78
# credit card  45462.51  46403.59
